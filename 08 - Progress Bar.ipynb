# %%
import pandas as pd
from tqdm import tqdm, tqdm_pandas
import numpy as np
from time import sleep

# %%
def slow_square(x):
    sleep(1)
    return x**2

# %%
df = pd.DataFrame(np.random.randint(0, 100, (100000, 6)))
tqdm_pandas(tqdm())
# Out:
# 0it [00:00, ?it/s]

# %%
df.groupby(0).progress_apply(slow_square)
# Out:
#           0     1     2     3     4     5
# 0      5329  6561  8649     4   625    81
# 1      3249   676   324  6400   441     0
# 2       121   196  4356  4356  1849  2401
# 3       225  4096  3249  6889  9216    49
# 4      3844  3136  9025  2209  1225  2025
# 5      7569  1089     0  3136  1521  9216
# 6      4624  2401  5184  4356  5776  2025
# 7      4356  5776   441  6400  8836  6724
# 8      9801  8464  9025  2916  2601    64
# 9      3600  6561  1089  2916  6084  4225
# 10     1444    16   841  1681  1521  3600
# 11     7569  3844  9604  1764  9025  5929
# 12     7225  4761  2025  5929  4356  3721
# 13     5625  7396   441  4900   121  6889
# 14     7744   784  9604  8281   144  1600
# 15     8464  5625   225  2025  8649  4225
# 16     5329   625   441    25  3969   529
# 17     1369  6400   441  3844  1936  6561
# 18     7569  7396     9  6724  3249  4356
# 19     3249  2025  1296  5929  3844  8464
# 20      100  8836  7056   400    25  2025
# ...
