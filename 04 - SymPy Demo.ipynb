# %%
from IPython.core.display import HTML
css = open('style_table.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
# 	margin: 0;
# 	font-family: Helvetica;
# }
# table.dataframe {
# 	border-collapse: collapse;
# 	border: none;
# }
# table.dataframe tr {
# 	border: none;
# }
# table.dataframe td, table.dataframe th {
# 	margin: 0;
# 	border: 1px solid white;
# 	padding-left: 0.25em;
# 	padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
# 	background-color: #fec;
# 	text-align: left;
# 	font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
# 	border-left: none;
# 	border-right: 1px dashed #888
# }
# table.dataframe td {
# 	border: 2px solid #ccf;
# 	background-color: #f4f4ff;
# }
# </style>

# %%
from IPython.display import IFrame

# %%
# %matplotlib inline

# %% [markdown]
# [Python: Cobb–Douglas production function with Sympy - Gappy Facets](http://gappyfacets.com/2015/06/25/python-cobb-douglas-production-function-with-sympy/#comment-743)

# %%
IFrame('http://www.sympy.org/en/index.html', width=1000, height=350)
# Out:
#         <iframe
#             width="1000"
#             height="350"
#             src="http://www.sympy.org/en/index.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
IFrame('http://gappyfacets.com/2015/06/25/python-cobb-douglas-production-function-with-sympy/', width=1000, height=350)
# Out:
#         <iframe
#             width="1000"
#             height="350"
#             src="http://gappyfacets.com/2015/06/25/python-cobb-douglas-production-function-with-sympy/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
import sympy as sym
import numpy as np
from matplotlib.pylab import plt

# %%
sym.init_printing(use_latex=True)

# %%
# Register Symbols
sym.var("L K Y A a")
# Out:
# (L, K, Y, A, a)

# %%
y = sym.Symbol('Y')

# %%
# Cobb-Douglass production function:
Y = ( A*(L**a) ) * ( K ** (1-a) )

# %%
sym.relational.Eq(y, Y)
# Out:
#        -a + 1  a
# Y = A⋅K      ⋅L

# %%
Ys = Y.subs({A: 10, a:0.6})

# %%
sym.plotting.plot3d(Ys, (K,0,10), (L,0,10))

# %%
# Turn sympy symbols into a python function:
Ys_func = sym.lambdify((K, L), Ys, "numpy")

# %%
# Make 2D permutation list with K=0~10 and L=0~10:
K_n = np.linspace(0,10, 50)
L_n = np.linspace(0,10, 50)

# %%
result = np.array([[Ys_func(k,l) for l in L_n] for k in K_n])

# %%
plt.matshow(result)
